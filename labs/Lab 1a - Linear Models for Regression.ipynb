# %% [markdown]
# # Lab 1: Linear models

# %% [markdown]
# ## Part 1: Regression

# %% [markdown]
# The [NO2 dataset](https://www.openml.org/d/547) contains 500 measurement of pollution caused by cars. The goal is to predict the concentration of $NO_2$ from data about traffic and atmospheric conditions. The predictive variables include the number of cars per hour, temperature, wind, and time of day.

# %%
# General imports
# %matplotlib inline
from preamble import *
plt.rcParams['savefig.dpi'] = 100 # This controls the size of your figures
from matplotlib import cm

# %%
# Download NO2 data. Takes a while the first time.
no2 = oml.datasets.get_dataset(547)
X, y, _, _ = no2.get_data(target=no2.default_target_attribute); 
attribute_names = list(X)

# %% [markdown]
# ## Quick visualization
# We can use pandas to quickly visualize the data. If you are new to pandas, take some time to understand the code.
#
# We'll remove the 'day' feature to focus on the non-temporal aspects of this interaction. We are not aiming to predict future levels, and even if we would it would require special treatment (e.g. different train-test splits). There also doesn't seem to be a long term trend in the data, even though there are clear periodic trends in temperature.

# %%
df = pd.DataFrame(X, columns=attribute_names).join(pd.DataFrame(list(y),columns=['target']))
df = df.sort_values(['day','hour_of_day']).drop('day',axis=1)
df.plot(use_index=False,figsize=(20,5),cmap=cm.get_cmap('brg'));
X = X.drop('day',axis=1)

# %%
df.head()
# Out:
#      cars_per_hour  temperature_at_2m  wind_speed  temperature_diff_2m_25m  \
# 42            7.64                8.5         4.3                     -0.2
# 20            7.75                8.2         4.5                      0.2
# 255           8.12                5.2         2.8                      0.3
# 488           7.64                6.7         2.3                     -0.4
# 94            8.32                6.3         1.2                      1.3
#
#      wind_direction  hour_of_day  target
# 42            322.0           13    3.22
# 20            307.0           14    3.15
# 255           209.0            8    4.20
# 488           247.0           10    3.98
# 94            265.0           17    4.14

# %% [markdown]
# If we plot the data, ordered by time of measurement, we can see that the wind direction (measured in angular degrees) is scaled very differently from the other features. Let's now zoom in to the other measures:

# %%
df.drop('wind_direction',axis=1).plot(use_index=False,figsize=(20,5),cmap=cm.get_cmap('brg'));

# %% [markdown]
# We can see that the target ($NO_2$ levels) seem to be correlated to the number of cars per hour, which makes sense because cars produce $NO_2$. Other influences (air temperature differences and wind) seem to have a more complex and subtle effect. Let's try to model these using linear regression models.

# %% [markdown]
# ## Exercise 1: Model benchmark
# It is clear that $NO_2$ concentrations depend on a combination of these features, so we will now try to learn this complex relationship. We first evaluate a range of linear regression problems, i.e. Linear Regression, Ridge, Lasso and ElasticNet, as well as kNN. Since we observed that somf features have very different scales, we'll also build pipelines of all these measures with an additional scaling step. For now, we'll stick to the default hyperparameter settings.

# %% [markdown]
# ### Exercise 1.1
# Implement a function below which evaluates each classifier passed into it on the given data, and then returns both the train and test scores of each as a list. You are allowed to import additional functions from whichever module you like, but you should be able to complete the function with [`cross_validate`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_validate.html) function and standard Python built-ins. Below you the function you will find example output.

# %%
from sklearn.model_selection import cross_validate

# %%
def evaluate_learners(models, X, y):
    """
    Given a list of models [model1, model2, ..., modelN] return two lists:
     - a list with the scores obtained on the training samples for each model,
     - a list with the test scores obtained on the test samples for each model.
     The order of scores should match the order in which the models were originally provided. E.g.:     
     [Model1 train score, ..., ModelN train score], [Model1 test score, ..., ModelN test score]
    """
    train_scores = []
    test_scores = []
    
    for model in models:
        scores = cross_validate(model, X, y, cv=5, n_jobs=3, return_train_score=True)
        
        train_scores.append(scores["train_score"].tolist())
        test_scores.append(scores["test_score"].tolist())
        
    return train_scores, test_scores

# # Example output:
# train_scores, test_scores = ([[0.92 , 0.924, 0.916, 0.917, 0.921],  # Model 1 train score for each of 5 folds.
#                               [0.963, 0.962, 0.953, 0.912, 0.934],  # Model 2 train score for each of 5 folds.
#                               ..
#                              [[0.801, 0.811, 0.806, 0.826, 0.804],  # Model 1 test score for each of 5 folds.
#                               [0.766, 0.756, 0.773, 0.756, 0.741],  # Model 2 test score for each of 5 folds.
#                               ..

# %% [markdown]
# ### Exercise 1.2
# Call the function you created with a Linear Regression, Ridge, Lasso and ElasticNet, as well as kNN.
# Store the return values in the variables `train_scores` and `test_scores`. Then, run the code given below to produce a plot visualizing the scores.

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.neighbors import KNeighborsRegressor

# %%
# %%time
models = [LinearRegression(), Ridge(), Lasso(), ElasticNet(), KNeighborsRegressor()]
train_scores, test_scores = evaluate_learners(models, X, y)
# Out:
# CPU times: user 50 ms, sys: 41.9 ms, total: 91.9 ms
# Wall time: 904 ms

# %%
# Plot a bar chart of the train and test scores of all the classifiers, including the variance as error bars
fig, ax = plt.subplots(figsize=(10,6))
width=0.45

ax.barh(np.arange(len(train_scores)), np.mean(test_scores, axis=1), width,
        yerr= np.std(test_scores, axis=1), color='green', label='test R^2')
ax.barh(np.arange(len(train_scores))-width, np.mean(train_scores, axis=1), width,
        yerr= np.std(train_scores, axis=1), color='red', label='train R^2')
for i, te, tr in zip(np.arange(len(train_scores)),test_scores,train_scores):
    ax.text(0, i, "{:.3f} +- {:.3f}".format(np.mean(te),np.std(te)), color=('white' if np.mean(te)>0.1 else 'black'), va='center')
    ax.text(0, i-width, "{:.3f} +- {:.3f}".format(np.mean(tr),np.std(tr)), color=('white' if np.mean(tr)>0.1 else 'black'), va='center')
labels = [c.__class__.__name__ if not hasattr(c, 'steps') else c.steps[0][0] + "_" + c.steps[1][0] for c in models]
ax.set(yticks=np.arange(len(train_scores))-width/2, yticklabels=labels)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2)

plt.show()

# %% [markdown]
# ### Exercise 1.3
# Interpret the plot. Which is the best regressor? Are any of the models overfitting? If so, what can we do to solve this? Is there a lot of variance in the results?

# %% [markdown]
# **Answer**
#
# Although all the scores are not great, Linear Regression and Ridge perform the best. Lasso and ElasticNet both perform poorly and Lasso seems to even overfit the data since the train scores is about 3 times as high as the test score. The same can be said about KNN which also has a way higher train than test score.

# %% [markdown]
# ## Exercise 2: Regularization
# We will now tune these algorithm's main regularization hyperparameter: the regularization hyperparameter (`alpha`) in Lasso and Ridge, and the number of neighbors (`n_neighbors`) in kNN.
#
# We expect the optimum for the alpha parameters to lie in $[10^{-12},10^{12}]$ and for n_neighbors between 1 and 50. alpha should be varied on a log scale (i.e. [0.01, 0.1, 1, 10, 100]), n_neighbors should be varied uniformly (i.e. [1,2,3,4]).

# %% [markdown]
# ### Exercise 2.1
# Vary the hyperparameters in the range given above and, for each regressor, create a line plot that plots both the training and test score for every value of the regularization hyperparameter. Hence, you should produce 3 plots, one for each regressor. Use the default 5-fold cross validation for all scores, but only plot the means.
#
# Hints:
# * Think about the time complexity of these models. Trying too many hyperparameter values may take too much time.
# * You can make use of numpy's [logspace](https://docs.scipy.org/doc/numpy/reference/generated/numpy.logspace.html), [geomspace](https://docs.scipy.org/doc/numpy/reference/generated/numpy.geomspace.html?highlight=geomspace#numpy.geomspace), and [linspace](https://docs.scipy.org/doc/numpy/reference/generated/numpy.linspace.html#numpy.linspace) functions.
# * You can use matplotlib's default [plot](https://matplotlib.org/tutorials/introductory/pyplot.html) function to plot the train and test scores.
# * You can manually loop over the hyperparameter ranges, or you can already check out scikit-learn's [GridSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html) function to save some programming. We'll see it again later in the course.

# %%
from sklearn.model_selection import GridSearchCV

# %%
def optimize_learners(models, parameters, X, y):
    """
    Given a list of models [model1, model2, ..., modelN] and parameters [params1, params2, ..., paramsN]
    run grid search on the model and parameters and return two lists:
     - a list with the scores obtained on the training samples for each model,
     - a list with the test scores obtained on the test samples for each model.
     The order of scores should match the order in which the models were originally provided. E.g.:     
     [Model1 train score, ..., ModelN train score], [Model1 test score, ..., ModelN test score]
    """
    train_scores = []
    test_scores = []
    
    for model, grid in zip(models, parameters):
        grid_search = GridSearchCV(model, grid, cv=3, n_jobs=3, return_train_score=True)
        grid_search.fit(X, y)
        
        train_scores.append(grid_search.cv_results_["mean_train_score"].tolist())
        test_scores.append(grid_search.cv_results_["mean_test_score"].tolist())
    
    return train_scores, test_scores

# %%
# %%time
models = [
    Lasso(),
    Ridge(),
    ElasticNet(),
    KNeighborsRegressor(),
]
parameters = [
    {"alpha": np.logspace(-12, 12, num=20)},
    {"alpha": np.logspace(-12, 12, num=20)},
    {"l1_ratio": np.linspace(0, 1, num=11), "alpha": np.logspace(-12, 12, num=25)},
    {"n_neighbors": np.linspace(1, 50, num=20, dtype=np.intc)},
]
train_scores, test_scores = optimize_learners(models, parameters, X, y)
# Out:
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49.07965978003972, tolerance: 0.02012960433204925
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.376679818344364, tolerance: 0.018996362410883667
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.37667982313808, tolerance: 0.018996362410883667
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49.07965978471176, tolerance: 0.02012960433204925
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.192483311232415, tolerance: 0.017010774893071647
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.376680350456766, tolerance: 0.018996362410883667
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49.07966025186696, tolerance: 0.02012960433204925
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.19248374621003, tolerance: 0.017010774893071647
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.3772124546826, tolerance: 0.018996362410883667
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49.080131646721696, tolerance: 0.02012960433204925
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.192922671164176, tolerance: 0.017010774893071647
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.901288633240796, tolerance: 0.018996362410883667
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49.54434789031003, tolerance: 0.02012960433204925
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.62496762990082, tolerance: 0.017010774893071647
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 82.32977243555135, tolerance: 0.018996362410883667
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 83.8908845004796, tolerance: 0.02012960433204925
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 73.32299984090255, tolerance: 0.017010774893071647
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94.87680063173187, tolerance: 0.018996362410883667
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 99.15314513468458, tolerance: 0.02012960433204925
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 84.50003026235593, tolerance: 0.017010774893071647
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94.98166992649675, tolerance: 0.018996362410883667
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100.64539835132544, tolerance: 0.02012960433204925
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 85.05293136956756, tolerance: 0.017010774893071647
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94.98181191222747, tolerance: 0.018996362410883667
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.192483306882636, tolerance: 0.017010774893071647
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49.0796597804648, tolerance: 0.02012960433204925
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.19248330727787, tolerance: 0.017010774893071647
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.37667987107613, tolerance: 0.018996362410883667
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49.079659827180514, tolerance: 0.02012960433204925
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.19248335077581, tolerance: 0.017010774893071647
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.37673308223377, tolerance: 0.018996362410883667
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49.079706967323176, tolerance: 0.02012960433204925
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.19252724390143, tolerance: 0.017010774893071647
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.42986280490801, tolerance: 0.018996362410883667
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49.12677425265932, tolerance: 0.02012960433204925
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.23635052891381, tolerance: 0.017010774893071647
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 66.92854303534473, tolerance: 0.018996362410883667
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 68.37451368541656, tolerance: 0.02012960433204925
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 59.756831863254924, tolerance: 0.017010774893071647
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94.36579291095396, tolerance: 0.018996362410883667
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97.22179400991247, tolerance: 0.02012960433204925
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 83.61627155974068, tolerance: 0.017010774893071647
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94.98039640384104, tolerance: 0.018996362410883667
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100.62196852132593, tolerance: 0.02012960433204925
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 85.04450468478657, tolerance: 0.017010774893071647
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94.98181063251565, tolerance: 0.018996362410883667
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100.64799540720743, tolerance: 0.02012960433204925
#   model = cd_fast.enet_coordinate_descent(
# /home/tomdewildt/Projects/data-mining/venv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 85.05386502761986, tolerance: 0.017010774893071647
#   model = cd_fast.enet_coordinate_descent(
# CPU times: user 403 ms, sys: 16.5 ms, total: 419 ms
# Wall time: 1.97 s

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, figsize=(10, 6))

ax1.set_title("Lasso")
ax1.set_xscale('log')
ax1.plot(parameters[0]["alpha"], train_scores[0], ".-", color="red", label="train")
ax1.plot(parameters[0]["alpha"], test_scores[0], ".-", color="green", label="test")
ax1.legend(bbox_to_anchor=(1.05, 1), loc=2)

ax2.set_title("Ridge")
ax2.set_xscale('log')
ax2.plot(parameters[1]["alpha"], train_scores[1], ".-", color="red", label="train")
ax2.plot(parameters[1]["alpha"], test_scores[1], ".-", color="green", label="test")
ax2.legend(bbox_to_anchor=(1.05, 1), loc=2)

ax3.set_title("KNN")
ax3.set_xscale('log')
ax3.plot(parameters[3]["n_neighbors"], train_scores[3], ".-", color="red", label="train")
ax3.plot(parameters[3]["n_neighbors"], test_scores[3], ".-", color="green", label="test")
ax3.legend(bbox_to_anchor=(1.05, 1), loc=2)

# %% [markdown]
# ### Exercise 2.2
# Interpret the plots. When are the methods underfitting? When are they overfitting? How sensitive are they to the regularization hyperparameter?

# %% [markdown]
# **Answer**
#
# Lasso is immediately dropping in score as soon as the alpha values becomes larger than 0.1, Ridge seems to drop in score after the value becomes larger than 10. Thus Lasso and Ridge are both quite sensitive to regularization hyperparameter alpha. Neither of the models seem to overfit or underfit the data.

# %% [markdown]
# ### Exercise 2.3
# ElasticNet allows to mix L1 and L2 loss, and the `l1_ratio` hyperparameter defines the ratio of L1 loss. Hence, it has two interacting hyperparameters: l1_ratio and alpha. Run a grid search to obtain a matrix of l1_ratio and alpha values and the resulting cross-validation scores. Then, use the function provided below to plot a heatmap of all values and interpret the result. Can you explain how the two hyperparameters interact?

# %%
# Generic heatmap
def heatmap(values, xlabel, ylabel, xticklabels, yticklabels, cmap=None,
            vmin=None, vmax=None, ax=None, fmt="%0.2f", printvalues=False):
    """
    Plots a heatmap for the performance of a model for every combination of two hyperparameter values
    
    values: nxn array with all evaluation results, varying the first hyperparameter first
    xlabel: name of the first hyperparameter
    ylabel: name of the second hyperparameter
    xticklabels: values of the first hyperparameter
    yticklabels: values of the second hyperparameter
    cmap: colormap
    vmin: minimal score
    vmax: maximal score
    ax: plot axes
    fmt: format for printing the scores
    printvalues: whether to print the scores
    """
    if ax is None:
        ax = plt.gca()
    img = ax.pcolor(values, cmap=cmap, vmin=None, vmax=None)
    img.update_scalarmappable()
    ax.set_xlabel(xlabel, fontsize=10)
    ax.set_ylabel(ylabel, fontsize=10)
    ax.set_xticks(np.arange(len(xticklabels)) + .5)
    ax.set_yticks(np.arange(len(yticklabels)) + .5)
    ax.set_xticklabels(xticklabels)
    ax.set_yticklabels(yticklabels)
    ax.set_aspect(1)
    
    ax.tick_params(axis='y', labelsize=12)
    ax.tick_params(axis='x', labelsize=12, labelrotation=90)

    if(printvalues):
        for p, color, value in zip(img.get_paths(), img.get_facecolors(), img.get_array()):
            x, y = p.vertices[:-2, :].mean(0)
            if np.mean(color[:3]) > 0.5:
                c = 'k'
            else:
                c = 'w'
            ax.text(x, y, fmt % value, color=c, ha="center", va="center", size=10)
    return img

# %%
fig, ax = plt.subplots(1, figsize=(10, 10))

heatmap(
    np.array(test_scores[2]).reshape(len(parameters[2]["alpha"]), len(parameters[2]["l1_ratio"])).T,
    xlabel="alpha",
    ylabel="l1_ratio",
    xticklabels=parameters[2]["alpha"],
    yticklabels=parameters[2]["l1_ratio"],
    ax=ax
)

# %% [markdown]
# ## Exercise 3: Visualizing coefficients
# Finally, let's verify whether the different optimized linear models also find the same coefficients.
#
# ### Exercise 3.1
# Draw a [scatterplot](https://matplotlib.org/gallery/shapes_and_collections/scatter.html) plotting the coefficients of the different models in different colors. Do you see much difference between the different models?
#
# For all models, choose an alpha parameter that seems to work well in the previous exercise. When in doubt, use alpha=0.001.

# %%
models = [
    LinearRegression(),
    Lasso(alpha=0.001),
    Ridge(alpha=0.001),
    ElasticNet(alpha=0.001),
]

# %%
# %%time
coefficients = [model.fit(X, y).coef_ for model in models]
columns = X.columns.tolist()
# Out:
# CPU times: user 6.87 ms, sys: 3 ms, total: 9.87 ms
# Wall time: 8.75 ms

# %%
fig, ax = plt.subplots(1, figsize=(10, 10))

for idx, model in enumerate(models):
    ax.scatter(columns, coefficients[idx], label=model.__class__.__name__)

ax.legend()

# %% [markdown]
# ### Exercise 3.2
# Redraw the same plot but now using a large amount of regularization (e.g. alpha=1). What do you observe? Does this help you explain the performance difference between Ridge and Lasso in exercise 1.2?

# %%
models = [
    LinearRegression(),
    Lasso(alpha=1),
    Ridge(alpha=1),
    ElasticNet(alpha=1),
]

# %%
# %%time
coefficients = [model.fit(X, y).coef_ for model in models]
columns = X.columns.tolist()
# Out:
# CPU times: user 8.38 ms, sys: 229 µs, total: 8.61 ms
# Wall time: 7.64 ms

# %%
fig, ax = plt.subplots(1, figsize=(10, 10))

for idx, model in enumerate(models):
    ax.scatter(columns, coefficients[idx], label=model.__class__.__name__)

ax.legend()
