# %% [markdown]
# # Lab 8: Object recognition with convolutional neural networks
# In this lab we consider the [CIFAR dataset](https://www.openml.org/d/40926), but model it using convolutional neural networks instead of linear models.
# There is no separate tutorial, but you can find lots of examples in the lecture notebook on convolutional neural networks.

# %% [markdown]
# Tip: You can run these exercises faster on a GPU (but they will also run fine on a CPU). If you do not have a GPU locally, you can upload this notebook to Google Colab. You can enable GPU support at “runtime” -> “change runtime type”.

# %%
# %tensorflow_version 2.x
import tensorflow as tf
tf.config.experimental.list_physical_devices('GPU') # Check whether GPUs are available
# Out:
# 2021-12-01 23:39:46.319266: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-01 23:39:46.343311: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-01 23:39:46.343602: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !pip install --quiet openml
# Out:
# WARNING: You are using pip version 21.1.3; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/tomdewildt/Projects/data-mining/venv/bin/python -m pip install --upgrade pip' command.

# %%
# %matplotlib inline
import openml as oml
import matplotlib.pyplot as plt

# %%
# Download CIFAR data. Takes a while the first time.
# This version returns 3x32x32 resolution images. 
# If you feel like it, repeat the exercises with the 96x96x3 resolution version by using ID 41103 
cifar = oml.datasets.get_dataset(40926) 
X, y, _, _ = cifar.get_data(target=cifar.default_target_attribute, dataset_format='array'); 
cifar_classes = {0: "airplane", 1: "automobile", 2: "bird", 3: "cat", 4: "deer",
                 5: "dog", 6: "frog", 7: "horse", 8: "ship", 9: "truck"}

# %%
# The data is in a weird 3x32x32 format, we need to reshape and transpose
Xr = X.reshape((len(X),3,32,32)).transpose(0,2,3,1)

# %%
# Take some random examples, reshape to a 32x32 image and plot
from random import randint
fig, axes = plt.subplots(1, 5,  figsize=(10, 5))
for i in range(5):
    n = randint(0,len(Xr))
    # The data is stored in a 3x32x32 format, so we need to transpose it
    axes[i].imshow(Xr[n]/255)
    axes[i].set_xlabel((cifar_classes[int(y[n])]))
    axes[i].set_xticks(()), axes[i].set_yticks(())
plt.show();

# %% [markdown]
# ## Exercise 1: A simple model
# * Split the data into 80% training and 20% validation sets
# * Normalize the data to [0,1]
# * Build a ConvNet with 3 convolutional layers interspersed with MaxPooling layers, and one dense layer.
#     * Use at least 32 filters in the first layer and ReLU activation.
#     * Otherwise, make rational design choices or experiment a bit to see what works.
# * You should at least get 60% accuracy.
# * For training, you can try batch sizes of 64, and 20-50 epochs, but feel free to explore this as well
# * Plot and interpret the learning curves

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(Xr,y, stratify=y, train_size=0.8)

# %%
from tensorflow.keras.utils import to_categorical
X_train = X_train / 255.
X_test = X_test / 255.
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
from tensorflow.keras import layers
from tensorflow.keras import models

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=50, batch_size=64, verbose=0,
                    validation_data=(X_test, y_test))
# Out:
# 2021-12-01 23:39:49.545764: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-12-01 23:39:49.546756: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-01 23:39:49.547306: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-01 23:39:49.547812: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-01 23:39:50.239368: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-01 23:39:50.239599: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-01 23:39:50.239772: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-01 23:39:50.239938: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1975 MB memory:  -> device: 0, name: GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2021-12-01 23:39:50.613383: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-01 23:39:51.718489: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8101

# %%
import pandas as pd
import numpy as np
pd.DataFrame(history.history).plot(lw=2,style=['b:','r:','b-','r-']);
print("Max val_acc",np.max(history.history['val_accuracy']))
# Out:
# Max val_acc 0.637499988079071

# %% [markdown]
# Already decent performance but the model starts overfitting heavily after epoch 15.

# %% [markdown]
# ## Exercise 2: VGG-like model
# * Mimic the VGG model by building 3 'blocks' of 2 convolutional layers each
# * Do MaxPooling after each block
# * The first layer should have at least 32 filters
# * Use zero-padding to be able to build a deeper model
# * Use a dense layer with at least 128 hidden nodes.
# * Plot and interpret the learning curves

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=50, batch_size=64, verbose=1,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 250/250 [==============================] - 5s 15ms/step - loss: 2.0474 - accuracy: 0.2659 - val_loss: 1.7250 - val_accuracy: 0.3808
# Epoch 2/50
# 250/250 [==============================] - 3s 14ms/step - loss: 1.5919 - accuracy: 0.4264 - val_loss: 1.6816 - val_accuracy: 0.4067
# Epoch 3/50
# 250/250 [==============================] - 3s 13ms/step - loss: 1.3736 - accuracy: 0.5088 - val_loss: 1.2891 - val_accuracy: 0.5400
# Epoch 4/50
# 250/250 [==============================] - 3s 13ms/step - loss: 1.1875 - accuracy: 0.5774 - val_loss: 1.1686 - val_accuracy: 0.5835
# Epoch 5/50
# 250/250 [==============================] - 3s 13ms/step - loss: 1.0262 - accuracy: 0.6359 - val_loss: 1.1469 - val_accuracy: 0.5960
# Epoch 6/50
# 250/250 [==============================] - 3s 14ms/step - loss: 0.8903 - accuracy: 0.6901 - val_loss: 1.0235 - val_accuracy: 0.6492
# Epoch 7/50
# 250/250 [==============================] - 3s 14ms/step - loss: 0.7365 - accuracy: 0.7388 - val_loss: 1.1601 - val_accuracy: 0.6363
# Epoch 8/50
# 250/250 [==============================] - 3s 13ms/step - loss: 0.6108 - accuracy: 0.7868 - val_loss: 1.0896 - val_accuracy: 0.6482
# Epoch 9/50
# 250/250 [==============================] - 3s 13ms/step - loss: 0.4904 - accuracy: 0.8296 - val_loss: 1.2763 - val_accuracy: 0.6425
# Epoch 10/50
# 250/250 [==============================] - 3s 13ms/step - loss: 0.3755 - accuracy: 0.8683 - val_loss: 1.3023 - val_accuracy: 0.6562
# Epoch 11/50
# 250/250 [==============================] - 3s 13ms/step - loss: 0.2937 - accuracy: 0.8944 - val_loss: 1.4392 - val_accuracy: 0.6568
# Epoch 12/50
# 250/250 [==============================] - 3s 14ms/step - loss: 0.2321 - accuracy: 0.9186 - val_loss: 1.8577 - val_accuracy: 0.6240
# Epoch 13/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1987 - accuracy: 0.9316 - val_loss: 1.7759 - val_accuracy: 0.6342
# Epoch 14/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1612 - accuracy: 0.9466 - val_loss: 1.7772 - val_accuracy: 0.6417
# Epoch 15/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1537 - accuracy: 0.9486 - val_loss: 1.9480 - val_accuracy: 0.6597
# Epoch 16/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1321 - accuracy: 0.9572 - val_loss: 2.1218 - val_accuracy: 0.6432
# Epoch 17/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1340 - accuracy: 0.9568 - val_loss: 2.3749 - val_accuracy: 0.6340
# Epoch 18/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1200 - accuracy: 0.9605 - val_loss: 2.2741 - val_accuracy: 0.6578
# Epoch 19/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1202 - accuracy: 0.9612 - val_loss: 2.4852 - val_accuracy: 0.6388
# Epoch 20/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1104 - accuracy: 0.9647 - val_loss: 2.6023 - val_accuracy: 0.6200
# Epoch 21/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1005 - accuracy: 0.9671 - val_loss: 2.5746 - val_accuracy: 0.6490
# Epoch 22/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1018 - accuracy: 0.9662 - val_loss: 2.6437 - val_accuracy: 0.6440
# Epoch 23/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1032 - accuracy: 0.9676 - val_loss: 2.4236 - val_accuracy: 0.6367
# Epoch 24/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0997 - accuracy: 0.9684 - val_loss: 2.9456 - val_accuracy: 0.6360
# Epoch 25/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0883 - accuracy: 0.9738 - val_loss: 3.5553 - val_accuracy: 0.6217
# Epoch 26/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0980 - accuracy: 0.9694 - val_loss: 2.8408 - val_accuracy: 0.6565
# Epoch 27/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0936 - accuracy: 0.9712 - val_loss: 2.9556 - val_accuracy: 0.6475
# Epoch 28/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0921 - accuracy: 0.9743 - val_loss: 3.0489 - val_accuracy: 0.6507
# Epoch 29/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0900 - accuracy: 0.9739 - val_loss: 3.1178 - val_accuracy: 0.6565
# Epoch 30/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0876 - accuracy: 0.9739 - val_loss: 3.5244 - val_accuracy: 0.6540
# Epoch 31/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0848 - accuracy: 0.9762 - val_loss: 3.0214 - val_accuracy: 0.6607
# Epoch 32/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0902 - accuracy: 0.9746 - val_loss: 3.4914 - val_accuracy: 0.6595
# Epoch 33/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0897 - accuracy: 0.9749 - val_loss: 3.7986 - val_accuracy: 0.6453
# Epoch 34/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0838 - accuracy: 0.9765 - val_loss: 3.6490 - val_accuracy: 0.6430
# Epoch 35/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0934 - accuracy: 0.9756 - val_loss: 3.5878 - val_accuracy: 0.6478
# Epoch 36/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0819 - accuracy: 0.9774 - val_loss: 3.5681 - val_accuracy: 0.6578
# Epoch 37/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0902 - accuracy: 0.9762 - val_loss: 3.7456 - val_accuracy: 0.6450
# Epoch 38/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.0759 - accuracy: 0.9797 - val_loss: 3.8100 - val_accuracy: 0.6470
# Epoch 39/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0866 - accuracy: 0.9765 - val_loss: 3.6482 - val_accuracy: 0.6507
# Epoch 40/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0860 - accuracy: 0.9776 - val_loss: 4.8725 - val_accuracy: 0.6457
# Epoch 41/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0865 - accuracy: 0.9784 - val_loss: 4.1247 - val_accuracy: 0.6395
# Epoch 42/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0883 - accuracy: 0.9765 - val_loss: 3.7817 - val_accuracy: 0.6520
# Epoch 43/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0865 - accuracy: 0.9778 - val_loss: 4.6175 - val_accuracy: 0.6395
# Epoch 44/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0730 - accuracy: 0.9799 - val_loss: 4.5251 - val_accuracy: 0.6525
# Epoch 45/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0811 - accuracy: 0.9802 - val_loss: 4.0789 - val_accuracy: 0.6507
# Epoch 46/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0712 - accuracy: 0.9810 - val_loss: 4.0696 - val_accuracy: 0.6625
# Epoch 47/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0880 - accuracy: 0.9786 - val_loss: 4.1408 - val_accuracy: 0.6490
# Epoch 48/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0802 - accuracy: 0.9801 - val_loss: 4.3546 - val_accuracy: 0.6645
# Epoch 49/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0904 - accuracy: 0.9794 - val_loss: 4.2137 - val_accuracy: 0.6513
# Epoch 50/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.0903 - accuracy: 0.9780 - val_loss: 3.8784 - val_accuracy: 0.6478

# %%
pd.DataFrame(history.history).plot(lw=2,style=['b:','r:','b-','r-']);
print("Max val_acc",np.max(history.history['val_accuracy']))
# Out:
# Max val_acc 0.6644999980926514

# %% [markdown]
# Better result, but still overfitting heavily

# %% [markdown]
# ## Exercise 3: Regularization
# * Explore different ways to regularize your VGG-like model
#   * Try adding some dropout after every MaxPooling and Dense layer.
#     * What are good Dropout rates?
#   * Try batch nornmalization together with Dropout
# * Plot and interpret the learning curves

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.2))
model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.2))
model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.2))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(10, activation='softmax'))
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=50, batch_size=64, verbose=1,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 250/250 [==============================] - 5s 17ms/step - loss: 2.1193 - accuracy: 0.2142 - val_loss: 1.8468 - val_accuracy: 0.3305
# Epoch 2/50
# 250/250 [==============================] - 4s 16ms/step - loss: 1.6854 - accuracy: 0.3837 - val_loss: 1.5462 - val_accuracy: 0.4330
# Epoch 3/50
# 250/250 [==============================] - 4s 16ms/step - loss: 1.4768 - accuracy: 0.4714 - val_loss: 1.3709 - val_accuracy: 0.5023
# Epoch 4/50
# 250/250 [==============================] - 4s 16ms/step - loss: 1.3110 - accuracy: 0.5228 - val_loss: 1.2166 - val_accuracy: 0.5615
# Epoch 5/50
# 250/250 [==============================] - 4s 16ms/step - loss: 1.1795 - accuracy: 0.5785 - val_loss: 1.1562 - val_accuracy: 0.5835
# Epoch 6/50
# 250/250 [==============================] - 4s 17ms/step - loss: 1.0805 - accuracy: 0.6160 - val_loss: 1.0451 - val_accuracy: 0.6308 - accura
# Epoch 7/50
# 250/250 [==============================] - 4s 15ms/step - loss: 0.9920 - accuracy: 0.6480 - val_loss: 1.0042 - val_accuracy: 0.6525
# Epoch 8/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.9061 - accuracy: 0.6809 - val_loss: 1.0347 - val_accuracy: 0.6447
# Epoch 9/50
# 250/250 [==============================] - 4s 17ms/step - loss: 0.8315 - accuracy: 0.7057 - val_loss: 0.9282 - val_accuracy: 0.6798
# Epoch 10/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7718 - accuracy: 0.7286 - val_loss: 0.9283 - val_accuracy: 0.6808
# Epoch 11/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7207 - accuracy: 0.7484 - val_loss: 0.9610 - val_accuracy: 0.6687
# Epoch 12/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.6677 - accuracy: 0.7619 - val_loss: 0.9149 - val_accuracy: 0.7035
# Epoch 13/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.6266 - accuracy: 0.7844 - val_loss: 0.9640 - val_accuracy: 0.6837
# Epoch 14/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.5811 - accuracy: 0.7952 - val_loss: 0.9873 - val_accuracy: 0.6975
# Epoch 15/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.5551 - accuracy: 0.8021 - val_loss: 0.9705 - val_accuracy: 0.7030
# Epoch 16/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.5160 - accuracy: 0.8196 - val_loss: 0.9826 - val_accuracy: 0.7130
# Epoch 17/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.4862 - accuracy: 0.8275 - val_loss: 1.0642 - val_accuracy: 0.7128
# Epoch 18/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.4666 - accuracy: 0.8355 - val_loss: 1.0583 - val_accuracy: 0.7138
# Epoch 19/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.4491 - accuracy: 0.8455 - val_loss: 1.0196 - val_accuracy: 0.7165
# Epoch 20/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.4406 - accuracy: 0.8478 - val_loss: 1.1246 - val_accuracy: 0.7130
# Epoch 21/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.4185 - accuracy: 0.8565 - val_loss: 1.2274 - val_accuracy: 0.7115
# Epoch 22/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.4065 - accuracy: 0.8627 - val_loss: 1.1142 - val_accuracy: 0.6955
# Epoch 23/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3965 - accuracy: 0.8669 - val_loss: 0.9851 - val_accuracy: 0.7070
# Epoch 24/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3899 - accuracy: 0.8676 - val_loss: 1.1589 - val_accuracy: 0.7063
# Epoch 25/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3793 - accuracy: 0.8726 - val_loss: 1.0864 - val_accuracy: 0.7285
# Epoch 26/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3694 - accuracy: 0.8770 - val_loss: 1.1316 - val_accuracy: 0.6980
# Epoch 27/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3785 - accuracy: 0.8758 - val_loss: 1.2802 - val_accuracy: 0.7023
# Epoch 28/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3703 - accuracy: 0.8783 - val_loss: 1.1800 - val_accuracy: 0.7212
# Epoch 29/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3741 - accuracy: 0.8790 - val_loss: 1.1629 - val_accuracy: 0.7128
# Epoch 30/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3855 - accuracy: 0.8783 - val_loss: 1.1659 - val_accuracy: 0.7197
# Epoch 31/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3579 - accuracy: 0.8833 - val_loss: 1.3959 - val_accuracy: 0.7132
# Epoch 32/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3764 - accuracy: 0.8802 - val_loss: 1.0342 - val_accuracy: 0.7115
# Epoch 33/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3614 - accuracy: 0.8861 - val_loss: 1.3804 - val_accuracy: 0.7268
# Epoch 34/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3798 - accuracy: 0.8787 - val_loss: 0.9917 - val_accuracy: 0.6977
# Epoch 35/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3709 - accuracy: 0.8842 - val_loss: 1.9104 - val_accuracy: 0.6842
# Epoch 36/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3644 - accuracy: 0.8856 - val_loss: 1.6967 - val_accuracy: 0.7045
# Epoch 37/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3803 - accuracy: 0.8791 - val_loss: 1.0307 - val_accuracy: 0.7100
# Epoch 38/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3796 - accuracy: 0.8844 - val_loss: 1.0464 - val_accuracy: 0.7160
# Epoch 39/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3848 - accuracy: 0.8811 - val_loss: 1.0726 - val_accuracy: 0.7045
# Epoch 40/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3932 - accuracy: 0.8802 - val_loss: 1.2214 - val_accuracy: 0.7088
# Epoch 41/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3987 - accuracy: 0.8776 - val_loss: 1.1728 - val_accuracy: 0.7178
# Epoch 42/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3997 - accuracy: 0.8767 - val_loss: 1.1861 - val_accuracy: 0.7107
# Epoch 43/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3999 - accuracy: 0.8791 - val_loss: 1.2589 - val_accuracy: 0.7090
# Epoch 44/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3862 - accuracy: 0.8821 - val_loss: 1.0178 - val_accuracy: 0.7040
# Epoch 45/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.3972 - accuracy: 0.8778 - val_loss: 1.3259 - val_accuracy: 0.7145
# Epoch 46/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.4097 - accuracy: 0.8791 - val_loss: 0.9998 - val_accuracy: 0.6930
# Epoch 47/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.4055 - accuracy: 0.8796 - val_loss: 1.1364 - val_accuracy: 0.7063
# Epoch 48/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.4200 - accuracy: 0.8748 - val_loss: 1.0566 - val_accuracy: 0.7110
# Epoch 49/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.4057 - accuracy: 0.8756 - val_loss: 1.1010 - val_accuracy: 0.7013
# Epoch 50/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.4098 - accuracy: 0.8777 - val_loss: 1.2403 - val_accuracy: 0.7015

# %%
pd.DataFrame(history.history).plot(lw=2,style=['b:','r:','b-','r-']);
print("Max val_acc",np.max(history.history['val_accuracy']))
# Out:
# Max val_acc 0.7285000085830688

# %% [markdown]
# Accuracy is quite a bit better and overfitting seems lessened
#
# Another common approach is to gradually increase the amount of dropout. This forces layers deep in the model to regularize more than layers closer to the input.

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.2))
model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.3))
model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.4))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10, activation='softmax'))
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=50, batch_size=64, verbose=1,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 250/250 [==============================] - 5s 17ms/step - loss: 2.1033 - accuracy: 0.2222 - val_loss: 1.8208 - val_accuracy: 0.3282
# Epoch 2/50
# 250/250 [==============================] - 4s 16ms/step - loss: 1.7651 - accuracy: 0.3594 - val_loss: 1.8235 - val_accuracy: 0.3560
# Epoch 3/50
# 250/250 [==============================] - 4s 16ms/step - loss: 1.5841 - accuracy: 0.4271 - val_loss: 1.4624 - val_accuracy: 0.4565
# Epoch 4/50
# 250/250 [==============================] - 4s 16ms/step - loss: 1.4465 - accuracy: 0.4788 - val_loss: 1.3385 - val_accuracy: 0.5120
# Epoch 5/50
# 250/250 [==============================] - 4s 16ms/step - loss: 1.3233 - accuracy: 0.5258 - val_loss: 1.1718 - val_accuracy: 0.5677
# Epoch 6/50
# 250/250 [==============================] - 4s 16ms/step - loss: 1.2340 - accuracy: 0.5588 - val_loss: 1.1088 - val_accuracy: 0.5953
# Epoch 7/50
# 250/250 [==============================] - 4s 16ms/step - loss: 1.1665 - accuracy: 0.5868 - val_loss: 1.1200 - val_accuracy: 0.6065
# Epoch 8/50
# 250/250 [==============================] - 4s 16ms/step - loss: 1.0938 - accuracy: 0.6197 - val_loss: 1.0929 - val_accuracy: 0.6060
# Epoch 9/50
# 250/250 [==============================] - 4s 16ms/step - loss: 1.0402 - accuracy: 0.6367 - val_loss: 1.0373 - val_accuracy: 0.6365
# Epoch 10/50
# 250/250 [==============================] - 4s 16ms/step - loss: 1.0009 - accuracy: 0.6487 - val_loss: 1.0711 - val_accuracy: 0.6440
# Epoch 11/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.9572 - accuracy: 0.6708 - val_loss: 0.9092 - val_accuracy: 0.6855
# Epoch 12/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.9121 - accuracy: 0.6848 - val_loss: 0.9562 - val_accuracy: 0.6793
# Epoch 13/50
# 250/250 [==============================] - 4s 17ms/step - loss: 0.8847 - accuracy: 0.6942 - val_loss: 0.9002 - val_accuracy: 0.6925
# Epoch 14/50
# 250/250 [==============================] - 4s 17ms/step - loss: 0.8499 - accuracy: 0.7052 - val_loss: 0.9250 - val_accuracy: 0.6902
# Epoch 15/50
# 250/250 [==============================] - 4s 17ms/step - loss: 0.8302 - accuracy: 0.7141 - val_loss: 1.0180 - val_accuracy: 0.6585
# Epoch 16/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.8145 - accuracy: 0.7188 - val_loss: 0.8957 - val_accuracy: 0.7028
# Epoch 17/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7966 - accuracy: 0.7264 - val_loss: 0.8928 - val_accuracy: 0.7143
# Epoch 18/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7815 - accuracy: 0.7303 - val_loss: 0.8548 - val_accuracy: 0.7105
# Epoch 19/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7617 - accuracy: 0.7419 - val_loss: 0.9190 - val_accuracy: 0.7125
# Epoch 20/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7545 - accuracy: 0.7447 - val_loss: 0.9939 - val_accuracy: 0.6812
# Epoch 21/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7485 - accuracy: 0.7466 - val_loss: 0.8609 - val_accuracy: 0.7262
# Epoch 22/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7292 - accuracy: 0.7514 - val_loss: 0.9961 - val_accuracy: 0.7135
# Epoch 23/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7286 - accuracy: 0.7523 - val_loss: 1.0149 - val_accuracy: 0.6730
# Epoch 24/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7235 - accuracy: 0.7582 - val_loss: 0.8925 - val_accuracy: 0.7100
# Epoch 25/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7204 - accuracy: 0.7622 - val_loss: 0.8804 - val_accuracy: 0.7105
# Epoch 26/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7178 - accuracy: 0.7601 - val_loss: 0.8797 - val_accuracy: 0.7212
# Epoch 27/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7052 - accuracy: 0.7665 - val_loss: 0.9053 - val_accuracy: 0.7235
# Epoch 28/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7192 - accuracy: 0.7611 - val_loss: 0.8423 - val_accuracy: 0.7280
# Epoch 29/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7165 - accuracy: 0.7621 - val_loss: 0.9053 - val_accuracy: 0.7212
# Epoch 30/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7316 - accuracy: 0.7576 - val_loss: 0.9271 - val_accuracy: 0.7082
# Epoch 31/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7216 - accuracy: 0.7623 - val_loss: 0.9410 - val_accuracy: 0.6948
# Epoch 32/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7421 - accuracy: 0.7606 - val_loss: 0.8558 - val_accuracy: 0.7200
# Epoch 33/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7415 - accuracy: 0.7558 - val_loss: 0.9033 - val_accuracy: 0.7172
# Epoch 34/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7257 - accuracy: 0.7637 - val_loss: 0.8720 - val_accuracy: 0.7370
# Epoch 35/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7432 - accuracy: 0.7637 - val_loss: 0.8294 - val_accuracy: 0.7358
# Epoch 36/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7446 - accuracy: 0.7628 - val_loss: 0.8668 - val_accuracy: 0.7210
# Epoch 37/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7474 - accuracy: 0.7582 - val_loss: 0.9499 - val_accuracy: 0.6967
# Epoch 38/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7533 - accuracy: 0.7546 - val_loss: 0.8779 - val_accuracy: 0.7230
# Epoch 39/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7546 - accuracy: 0.7562 - val_loss: 0.8669 - val_accuracy: 0.7300
# Epoch 40/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7451 - accuracy: 0.7606 - val_loss: 0.8872 - val_accuracy: 0.7347
# Epoch 41/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7334 - accuracy: 0.7606 - val_loss: 0.8710 - val_accuracy: 0.7235
# Epoch 42/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7287 - accuracy: 0.7657 - val_loss: 0.9097 - val_accuracy: 0.7113
# Epoch 43/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7603 - accuracy: 0.7524 - val_loss: 0.9465 - val_accuracy: 0.6910
# Epoch 44/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7491 - accuracy: 0.7576 - val_loss: 0.8598 - val_accuracy: 0.7280
# Epoch 45/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7579 - accuracy: 0.7579 - val_loss: 0.8408 - val_accuracy: 0.7287
# Epoch 46/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7816 - accuracy: 0.7541 - val_loss: 0.9582 - val_accuracy: 0.7030
# Epoch 47/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7637 - accuracy: 0.7537 - val_loss: 0.8444 - val_accuracy: 0.7175
# Epoch 48/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7842 - accuracy: 0.7544 - val_loss: 0.8716 - val_accuracy: 0.7253
# Epoch 49/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7614 - accuracy: 0.7548 - val_loss: 0.9234 - val_accuracy: 0.6938
# Epoch 50/50
# 250/250 [==============================] - 4s 16ms/step - loss: 0.7711 - accuracy: 0.7544 - val_loss: 0.8280 - val_accuracy: 0.7340

# %%
pd.DataFrame(history.history).plot(lw=2,style=['b:','r:','b-','r-']);
print("Max val_acc",np.max(history.history['val_accuracy']))
# Out:
# Max val_acc 0.7369999885559082

# %% [markdown]
# Slightly better accuracy and very little overfitting remains.
#
# Next, we try adding Batch Normalization.

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.2))
model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.3))
model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.4))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10, activation='softmax'))
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=50, batch_size=64, verbose=1,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 250/250 [==============================] - 6s 21ms/step - loss: 2.0781 - accuracy: 0.3272 - val_loss: 3.3510 - val_accuracy: 0.1290
# Epoch 2/50
# 250/250 [==============================] - 5s 20ms/step - loss: 1.4313 - accuracy: 0.4963 - val_loss: 1.8612 - val_accuracy: 0.3655
# Epoch 3/50
# 250/250 [==============================] - 5s 19ms/step - loss: 1.1580 - accuracy: 0.5931 - val_loss: 1.2538 - val_accuracy: 0.5798
# Epoch 4/50
# 250/250 [==============================] - 5s 19ms/step - loss: 1.0076 - accuracy: 0.6450 - val_loss: 0.9981 - val_accuracy: 0.6605
# Epoch 5/50
# 250/250 [==============================] - 5s 19ms/step - loss: 0.8914 - accuracy: 0.6906 - val_loss: 0.9741 - val_accuracy: 0.6605
# Epoch 6/50
# 250/250 [==============================] - 5s 19ms/step - loss: 0.8128 - accuracy: 0.7172 - val_loss: 0.8714 - val_accuracy: 0.7000
# Epoch 7/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.7519 - accuracy: 0.7381 - val_loss: 0.8074 - val_accuracy: 0.7178
# Epoch 8/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.6894 - accuracy: 0.7591 - val_loss: 0.8318 - val_accuracy: 0.7143
# Epoch 9/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.6431 - accuracy: 0.7775 - val_loss: 0.7567 - val_accuracy: 0.7385
# Epoch 10/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.5979 - accuracy: 0.7899 - val_loss: 0.8509 - val_accuracy: 0.7260
# Epoch 11/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.5605 - accuracy: 0.8068 - val_loss: 0.7332 - val_accuracy: 0.7500
# Epoch 12/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.5250 - accuracy: 0.8189 - val_loss: 0.7580 - val_accuracy: 0.7465
# Epoch 13/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.4903 - accuracy: 0.8287 - val_loss: 0.7692 - val_accuracy: 0.7545
# Epoch 14/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.4732 - accuracy: 0.8338 - val_loss: 0.8283 - val_accuracy: 0.7408
# Epoch 15/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.4450 - accuracy: 0.8456 - val_loss: 0.8935 - val_accuracy: 0.7325
# Epoch 16/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.4267 - accuracy: 0.8516 - val_loss: 0.7305 - val_accuracy: 0.7670
# Epoch 17/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.3978 - accuracy: 0.8604 - val_loss: 0.9184 - val_accuracy: 0.7362
# Epoch 18/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.3807 - accuracy: 0.8681 - val_loss: 0.7655 - val_accuracy: 0.7707
# Epoch 19/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.3617 - accuracy: 0.8748 - val_loss: 0.7639 - val_accuracy: 0.7778
# Epoch 20/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.3470 - accuracy: 0.8798 - val_loss: 0.7731 - val_accuracy: 0.7660
# Epoch 21/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.3323 - accuracy: 0.8851 - val_loss: 0.7482 - val_accuracy: 0.7745
# Epoch 22/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.3201 - accuracy: 0.8880 - val_loss: 0.7289 - val_accuracy: 0.7845
# Epoch 23/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.3026 - accuracy: 0.8957 - val_loss: 0.7428 - val_accuracy: 0.7830
# Epoch 24/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.2880 - accuracy: 0.8995 - val_loss: 0.8552 - val_accuracy: 0.7545
# Epoch 25/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.2856 - accuracy: 0.8985 - val_loss: 0.8823 - val_accuracy: 0.7665
# Epoch 26/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.2852 - accuracy: 0.9014 - val_loss: 1.0785 - val_accuracy: 0.7272
# Epoch 27/50
# 250/250 [==============================] - 5s 21ms/step - loss: 0.2701 - accuracy: 0.9062 - val_loss: 0.7695 - val_accuracy: 0.7958
# Epoch 28/50
# 250/250 [==============================] - 5s 21ms/step - loss: 0.2574 - accuracy: 0.9092 - val_loss: 0.7527 - val_accuracy: 0.7862
# Epoch 29/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.2504 - accuracy: 0.9144 - val_loss: 0.7809 - val_accuracy: 0.7883
# Epoch 30/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.2476 - accuracy: 0.9102 - val_loss: 0.7443 - val_accuracy: 0.7928
# Epoch 31/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.2364 - accuracy: 0.9182 - val_loss: 0.8622 - val_accuracy: 0.7765
# Epoch 32/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.2255 - accuracy: 0.9198 - val_loss: 0.8198 - val_accuracy: 0.7855
# Epoch 33/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.2180 - accuracy: 0.9244 - val_loss: 0.8164 - val_accuracy: 0.7830
# Epoch 34/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.2108 - accuracy: 0.9259 - val_loss: 0.8086 - val_accuracy: 0.7782
# Epoch 35/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.2188 - accuracy: 0.9236 - val_loss: 0.8507 - val_accuracy: 0.7782
# Epoch 36/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.1980 - accuracy: 0.9304 - val_loss: 0.8297 - val_accuracy: 0.7840
# Epoch 37/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.2007 - accuracy: 0.9296 - val_loss: 0.8130 - val_accuracy: 0.7870
# Epoch 38/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.2022 - accuracy: 0.9291 - val_loss: 0.8784 - val_accuracy: 0.7772
# Epoch 39/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.1929 - accuracy: 0.9321 - val_loss: 0.8240 - val_accuracy: 0.7950
# Epoch 40/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.1828 - accuracy: 0.9360 - val_loss: 0.8744 - val_accuracy: 0.7678
# Epoch 41/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.1995 - accuracy: 0.9319 - val_loss: 0.8418 - val_accuracy: 0.7908
# Epoch 42/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.1919 - accuracy: 0.9328 - val_loss: 0.8090 - val_accuracy: 0.7958
# Epoch 43/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.1871 - accuracy: 0.9361 - val_loss: 0.8193 - val_accuracy: 0.7995
# Epoch 44/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.1694 - accuracy: 0.9424 - val_loss: 1.0598 - val_accuracy: 0.7368
# Epoch 45/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.1787 - accuracy: 0.9377 - val_loss: 0.8060 - val_accuracy: 0.7972
# Epoch 46/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.1734 - accuracy: 0.9413 - val_loss: 0.9053 - val_accuracy: 0.7835
# Epoch 47/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.1640 - accuracy: 0.9425 - val_loss: 0.9039 - val_accuracy: 0.7832
# Epoch 48/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.1766 - accuracy: 0.9411 - val_loss: 0.8211 - val_accuracy: 0.7990
# Epoch 49/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.1595 - accuracy: 0.9426 - val_loss: 0.7760 - val_accuracy: 0.7983
# Epoch 50/50
# 250/250 [==============================] - 5s 20ms/step - loss: 0.1599 - accuracy: 0.9454 - val_loss: 0.8209 - val_accuracy: 0.7925

# %%
pd.DataFrame(history.history).plot(lw=2,style=['b:','r:','b-','r-']);
print("Max val_acc",np.max(history.history['val_accuracy']))
# Out:
# Max val_acc 0.7994999885559082

# %% [markdown]
# ## Exercise 4: Data Augmentation
# * Perform image augmentation. You can use the ImageDataGenerator for this.
# * What is the effect? What is the effect with and without Dropout?
# * Plot and interpret the learning curves

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,)
it_train = train_datagen.flow(X_train, y_train, batch_size=64)

# %%
from tensorflow.keras import layers
from tensorflow.keras import models

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.2))
model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.3))
model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.4))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10, activation='softmax'))
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

steps = int(X_train.shape[0] / 64)
history = model.fit(it_train, epochs=50, steps_per_epoch=steps, verbose=1,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 250/250 [==============================] - 8s 26ms/step - loss: 2.1594 - accuracy: 0.3173 - val_loss: 4.3374 - val_accuracy: 0.1625
# Epoch 2/50
# 250/250 [==============================] - 6s 24ms/step - loss: 1.5675 - accuracy: 0.4515 - val_loss: 1.3726 - val_accuracy: 0.5270
# Epoch 3/50
# 250/250 [==============================] - 8s 30ms/step - loss: 1.3282 - accuracy: 0.5275 - val_loss: 1.1660 - val_accuracy: 0.5880
# Epoch 4/50
# 250/250 [==============================] - 7s 29ms/step - loss: 1.1551 - accuracy: 0.5876 - val_loss: 1.1754 - val_accuracy: 0.5847
# Epoch 5/50
# 250/250 [==============================] - 7s 27ms/step - loss: 1.0636 - accuracy: 0.6251 - val_loss: 1.0885 - val_accuracy: 0.6382
# Epoch 6/50
# 250/250 [==============================] - 6s 25ms/step - loss: 0.9810 - accuracy: 0.6566 - val_loss: 0.9645 - val_accuracy: 0.6543
# Epoch 7/50
# 250/250 [==============================] - 6s 25ms/step - loss: 0.9306 - accuracy: 0.6703 - val_loss: 1.0140 - val_accuracy: 0.6545
# Epoch 8/50
# 250/250 [==============================] - 6s 25ms/step - loss: 0.8787 - accuracy: 0.6973 - val_loss: 0.9653 - val_accuracy: 0.6775
# Epoch 9/50
# 250/250 [==============================] - 6s 25ms/step - loss: 0.8456 - accuracy: 0.7082 - val_loss: 1.0397 - val_accuracy: 0.6480
# Epoch 10/50
# 250/250 [==============================] - 6s 25ms/step - loss: 0.8117 - accuracy: 0.7193 - val_loss: 1.1288 - val_accuracy: 0.6252
# Epoch 11/50
# 250/250 [==============================] - 7s 28ms/step - loss: 0.7860 - accuracy: 0.7271 - val_loss: 0.7867 - val_accuracy: 0.7303
# Epoch 12/50
# 250/250 [==============================] - 7s 29ms/step - loss: 0.7634 - accuracy: 0.7359 - val_loss: 0.7772 - val_accuracy: 0.7402
# Epoch 13/50
# 250/250 [==============================] - 7s 27ms/step - loss: 0.7436 - accuracy: 0.7442 - val_loss: 0.6557 - val_accuracy: 0.7757
# Epoch 14/50
# 250/250 [==============================] - 6s 25ms/step - loss: 0.7157 - accuracy: 0.7566 - val_loss: 0.8615 - val_accuracy: 0.7225
# Epoch 15/50
# 250/250 [==============================] - 7s 27ms/step - loss: 0.6946 - accuracy: 0.7642 - val_loss: 0.7277 - val_accuracy: 0.7515
# Epoch 16/50
# 250/250 [==============================] - 6s 26ms/step - loss: 0.6854 - accuracy: 0.7681 - val_loss: 0.7875 - val_accuracy: 0.7310
# Epoch 17/50
# 250/250 [==============================] - 6s 24ms/step - loss: 0.6645 - accuracy: 0.7771 - val_loss: 0.7181 - val_accuracy: 0.7620
# Epoch 18/50
# 250/250 [==============================] - 8s 30ms/step - loss: 0.6452 - accuracy: 0.7757 - val_loss: 0.7085 - val_accuracy: 0.7563
# Epoch 19/50
# 250/250 [==============================] - 7s 29ms/step - loss: 0.6348 - accuracy: 0.7846 - val_loss: 0.6602 - val_accuracy: 0.7805
# Epoch 20/50
# 250/250 [==============================] - 6s 26ms/step - loss: 0.6323 - accuracy: 0.7828 - val_loss: 0.7491 - val_accuracy: 0.7667
# Epoch 21/50
# 250/250 [==============================] - 6s 26ms/step - loss: 0.6163 - accuracy: 0.7889 - val_loss: 1.0274 - val_accuracy: 0.7092
# Epoch 22/50
# 250/250 [==============================] - 6s 25ms/step - loss: 0.5984 - accuracy: 0.7977 - val_loss: 0.6826 - val_accuracy: 0.7800
# Epoch 23/50
# 250/250 [==============================] - 6s 25ms/step - loss: 0.5856 - accuracy: 0.7994 - val_loss: 0.7099 - val_accuracy: 0.7673
# Epoch 24/50
# 250/250 [==============================] - 7s 28ms/step - loss: 0.5947 - accuracy: 0.7968 - val_loss: 0.7401 - val_accuracy: 0.7565
# Epoch 25/50
# 250/250 [==============================] - 6s 24ms/step - loss: 0.5790 - accuracy: 0.8039 - val_loss: 0.8619 - val_accuracy: 0.7143
# Epoch 26/50
# 250/250 [==============================] - 6s 26ms/step - loss: 0.5671 - accuracy: 0.8062 - val_loss: 0.7431 - val_accuracy: 0.7598
# Epoch 27/50
# 250/250 [==============================] - 6s 25ms/step - loss: 0.5507 - accuracy: 0.8106 - val_loss: 0.6201 - val_accuracy: 0.7920
# Epoch 28/50
# 250/250 [==============================] - 7s 26ms/step - loss: 0.5356 - accuracy: 0.8166 - val_loss: 0.6161 - val_accuracy: 0.7952
# Epoch 29/50
# 250/250 [==============================] - 7s 28ms/step - loss: 0.5383 - accuracy: 0.8157 - val_loss: 0.6414 - val_accuracy: 0.7847
# Epoch 30/50
# 250/250 [==============================] - 7s 29ms/step - loss: 0.5410 - accuracy: 0.8148 - val_loss: 0.7594 - val_accuracy: 0.7582
# Epoch 31/50
# 250/250 [==============================] - 7s 27ms/step - loss: 0.5253 - accuracy: 0.8202 - val_loss: 0.6242 - val_accuracy: 0.8012
# Epoch 32/50
# 250/250 [==============================] - 6s 25ms/step - loss: 0.5306 - accuracy: 0.8184 - val_loss: 0.6960 - val_accuracy: 0.7818
# Epoch 33/50
# 250/250 [==============================] - 6s 25ms/step - loss: 0.5127 - accuracy: 0.8228 - val_loss: 0.7044 - val_accuracy: 0.7735
# Epoch 34/50
# 250/250 [==============================] - 6s 24ms/step - loss: 0.5069 - accuracy: 0.8254 - val_loss: 0.6563 - val_accuracy: 0.7925
# Epoch 35/50
# 250/250 [==============================] - 6s 25ms/step - loss: 0.5075 - accuracy: 0.8288 - val_loss: 0.6441 - val_accuracy: 0.7890
# Epoch 36/50
# 250/250 [==============================] - 7s 27ms/step - loss: 0.4956 - accuracy: 0.8296 - val_loss: 0.5496 - val_accuracy: 0.8217
# Epoch 37/50
# 250/250 [==============================] - 6s 24ms/step - loss: 0.4885 - accuracy: 0.8324 - val_loss: 0.6810 - val_accuracy: 0.7822
# Epoch 38/50
# 250/250 [==============================] - 6s 25ms/step - loss: 0.4874 - accuracy: 0.8319 - val_loss: 0.6858 - val_accuracy: 0.7862
# Epoch 39/50
# 250/250 [==============================] - 7s 29ms/step - loss: 0.4817 - accuracy: 0.8340 - val_loss: 0.5742 - val_accuracy: 0.8200
# Epoch 40/50
# 250/250 [==============================] - 7s 29ms/step - loss: 0.4720 - accuracy: 0.8370 - val_loss: 0.7747 - val_accuracy: 0.7548
# Epoch 41/50
# 250/250 [==============================] - 6s 24ms/step - loss: 0.4729 - accuracy: 0.8371 - val_loss: 0.6082 - val_accuracy: 0.7980
# Epoch 42/50
# 250/250 [==============================] - 6s 24ms/step - loss: 0.4690 - accuracy: 0.8394 - val_loss: 0.5980 - val_accuracy: 0.8090
# Epoch 43/50
# 250/250 [==============================] - 6s 24ms/step - loss: 0.4566 - accuracy: 0.8429 - val_loss: 0.6313 - val_accuracy: 0.7952
# Epoch 44/50
# 250/250 [==============================] - 6s 25ms/step - loss: 0.4563 - accuracy: 0.8439 - val_loss: 0.6075 - val_accuracy: 0.8048
# Epoch 45/50
# 250/250 [==============================] - 7s 29ms/step - loss: 0.4529 - accuracy: 0.8460 - val_loss: 0.5375 - val_accuracy: 0.8227
# Epoch 46/50
# 250/250 [==============================] - 6s 24ms/step - loss: 0.4460 - accuracy: 0.8452 - val_loss: 0.5337 - val_accuracy: 0.8173
# Epoch 47/50
# 250/250 [==============================] - 6s 25ms/step - loss: 0.4437 - accuracy: 0.8457 - val_loss: 0.5857 - val_accuracy: 0.8052
# Epoch 48/50
# 250/250 [==============================] - 6s 25ms/step - loss: 0.4405 - accuracy: 0.8507 - val_loss: 0.5733 - val_accuracy: 0.8202
# Epoch 49/50
# 250/250 [==============================] - 7s 26ms/step - loss: 0.4410 - accuracy: 0.8457 - val_loss: 0.6931 - val_accuracy: 0.7790
# Epoch 50/50
# 250/250 [==============================] - 7s 28ms/step - loss: 0.4302 - accuracy: 0.8534 - val_loss: 0.6148 - val_accuracy: 0.8077

# %%
import pandas as pd
import numpy as np
pd.DataFrame(history.history).plot(lw=2,style=['b:','r:','b-','r-']);
print("Max val_acc",np.max(history.history['val_accuracy']))
# Out:
# Max val_acc 0.8227499723434448

# %% [markdown]
# We get 2-3% improvement. We get the best results with very subtle data augmentation (small shifts and flips). The images are quite low resolution and rotation or sheer will destroy too much information.

# %% [markdown]
# ## Exercise 5: Interpreting misclassifications
# Chances are that even your best models are not yet perfect. It is important to understand what kind of errors it still makes.
# * Run the test images through the network and detect all misclassified ones
# * Interpret the results. Are these misclassifications to be expected?
# * Compute the confusion matrix. Which classes are often confused?

# %%
y_pred = model.predict(X_test)
misclassified_samples = np.nonzero(np.argmax(y_test, axis=1) != np.argmax(y_pred, axis=1))[0]

# %% [markdown]
# Since we have numeric outputs (a value per class), we need to take the class with the maximum value as the predicted class.

# %%
# Visualize the (first five) misclassifications, together with the predicted and actual class
fig, axes = plt.subplots(1, 5,  figsize=(10, 5))
for nr, i in enumerate(misclassified_samples[:5]):
    axes[nr].imshow(X_test[i])
    axes[nr].set_xlabel("Predicted: %s,\n Actual : %s" % (cifar_classes[np.argmax(y_pred[i])],cifar_classes[np.argmax(y_test[i])]))
    axes[nr].set_xticks(()), axes[nr].set_yticks(())

plt.show();

# %% [markdown]
# Some of these are indeed hard to categorize, although we can probably still improve the model quite a bit.

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(np.argmax(y_test, axis=1),np.argmax(y_pred, axis=1))
fig, ax = plt.subplots()
im = ax.imshow(cm)
ax.set_xticks(np.arange(10)), ax.set_yticks(np.arange(10))
ax.set_xticklabels(list(cifar_classes.values()), rotation=45, ha="right")
ax.set_yticklabels(list(cifar_classes.values()))
ax.set_ylabel('True')
ax.set_xlabel('Predicted')
for i in range(100):
    ax.text(int(i/10),i%10,cm[i%10,int(i/10)], ha="center", va="center", color="w")

# %% [markdown]
# Most misclassifications seem to involve cats, birds, and horses. The most common misclassification is between cats and dogs.

# %% [markdown]
# ## Exercise 6: Interpreting the model
# Retrain your best model on all the data. Next, retrieve and visualize the activations (feature maps) for every filter for every layer, or at least for a few filters for every layer. Tip: see the course notebooks for examples on how to do this.
#
# Interpret the results. Is your model indeed learning something useful?

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_33 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               262272
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 552,874
# Trainable params: 551,722
# Non-trainable params: 1,152
# _________________________________________________________________

# %%
from tensorflow.keras import models

img_tensor = X_test[4]
img_tensor = np.expand_dims(img_tensor, axis=0) 

# Extracts the outputs of the top 8 layers:
layer_outputs = [layer.output for layer in model.layers[:15]]
# Creates a model that will return these outputs, given the model input:
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)

# This will return a list of 5 Numpy arrays:
# one array per layer activation
activations = activation_model.predict(img_tensor)

# %%
plt.rcParams['figure.dpi'] = 120
first_layer_activation = activations[0]

f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.imshow(img_tensor[0])
ax2.matshow(first_layer_activation[0, :, :, 2], cmap='viridis')
ax1.set_xticks([])
ax1.set_yticks([])
ax2.set_xticks([])
ax2.set_yticks([])
ax1.set_xlabel('Input image')
ax2.set_xlabel('Activation of filter 2');

# %%
images_per_row = 16

layer_names = []
for layer in model.layers[:15]:
    layer_names.append(layer.name)

def plot_activations(layer_index, activations):
    start = layer_index
    end = layer_index+1
    # Now let's display our feature maps
    for layer_name, layer_activation in zip(layer_names[start:end], activations[start:end]):
        # This is the number of features in the feature map
        n_features = layer_activation.shape[-1]

        # The feature map has shape (1, size, size, n_features)
        size = layer_activation.shape[1]

        # We will tile the activation channels in this matrix
        n_cols = n_features // images_per_row
        display_grid = np.zeros((size * n_cols, images_per_row * size))

        # We'll tile each filter into this big horizontal grid
        for col in range(n_cols):
            for row in range(images_per_row):
                channel_image = layer_activation[0,
                                                 :, :,
                                                 col * images_per_row + row]
                # Post-process the feature to make it visually palatable
                channel_image -= channel_image.mean()
                channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                display_grid[col * size : (col + 1) * size,
                             row * size : (row + 1) * size] = channel_image

        # Display the grid
        scale = 1. / size
        plt.figure(figsize=(scale * display_grid.shape[1],
                            scale * display_grid.shape[0]))
        plt.title("Activation of layer {} ({})".format(layer_index+1,layer_name))
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='viridis')

    plt.show()

# %%
plot_activations(0, activations);
# Out:
# /tmp/ipykernel_110242/2702396986.py:30: RuntimeWarning: invalid value encountered in true_divide
#   channel_image /= channel_image.std()

# %%
plot_activations(2, activations);

# %%
plot_activations(6, activations);

# %%
plot_activations(8, activations)

# %%
plot_activations(12, activations)
# Out:
# /tmp/ipykernel_110242/2702396986.py:30: RuntimeWarning: invalid value encountered in true_divide
#   channel_image /= channel_image.std()

# %% [markdown]
# ## Optional: Take it a step further
# * Repeat the exercises, but now use a [higher-resolution version of the CIFAR dataset](https://www.openml.org/d/40926) (with OpenML ID 41103), or another [version with 100 classes](https://www.openml.org/d/41983) (with OpenML ID 41983). Good luck!
